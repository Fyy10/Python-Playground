# %% [markdown]
# ![](https://ai-studio-static-online.cdn.bcebos.com/61c6f63d666f4a81b98171b775ee8d486e610cf8fa654225b5cdd3c4b7db96ce)本项目对应视频课程已上线，点击前往学习[深度学习CV从入门到实战](https://aistudio.baidu.com/aistudio/course/introduce/789)-课节9猫狗视频实战讲解

# %% [markdown]
# 图像分类是根据图像的语义信息将不同类别图像区分开来，是计算机视觉中重要的基本问题
#
# 猫狗分类属于图像分类中的粗粒度分类问题
#
# ![](https://ai-studio-static-online.cdn.bcebos.com/1cd9ef37036647c2afbbc866a7d2c14179f33cf1e2494d1f8f00de556d231452)

# %% [markdown]
# 实践总体过程和步骤如下图

# %% [markdown]
# ![](https://ai-studio-static-online.cdn.bcebos.com/b008c158886547649a9b06f6ae96df44447427fe65db4bac82b609334bd0d25c)

# %% [markdown]
# **首先导入必要的包**
#
# paddle.fluid--->PaddlePaddle深度学习框架
#
# os------------->python的模块，可使用该模块对操作系统进行操作

# %%
#导入需要的包
import paddle as paddle
import paddle.fluid as fluid
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import os

# %% [markdown]
# # **Step1:准备数据**
# **（1）数据集介绍**
#
# 我们使用CIFAR10数据集。CIFAR10数据集包含60,000张32x32的彩色图片，10个类别，每个类包含6,000张。其中50,000张图片作为训练集，10000张作为验证集。这次我们只对其中的猫和狗两类进行预测。
#
# ![](https://ai-studio-static-online.cdn.bcebos.com/567016c028714d21bfe690dee70e9ea31512ba3575bd4d7caebbb7ade05c72ac)
#
# **(2)train_reader和test_reader**
#
# paddle.dataset.cifar.train10()和test10()分别获取cifar训练集和测试集
#
# paddle.reader.shuffle()表示每次缓存BUF_SIZE个数据项，并进行打乱
#
# paddle.batch()表示每BATCH_SIZE组成一个batch
#
# **（3）数据集下载**
#
# 由于本次实践的数据集稍微比较大，以防出现不好下载的问题，为了提高效率，可以用下面的代码进行数据集的下载。
# ```
#
# !mkdir -p /home/aistudio/.cache/paddle/dataset/cifar/
#
# !wget "http://ai-atest.bj.bcebos.com/cifar-10-python.tar.gz" -O cifar-10-python.tar.gz
#
# !mv cifar-10-python.tar.gz /home/aistudio/.cache/paddle/dataset/cifar/
# ```

# %%
# !mkdir -p  /home/aistudio/.cache/paddle/dataset/cifar/
# !wget "http://ai-atest.bj.bcebos.com/cifar-10-python.tar.gz" -O cifar-10-python.tar.gz
# !mv cifar-10-python.tar.gz  /home/aistudio/.cache/paddle/dataset/cifar/
# !ls -a /home/aistudio/.cache/paddle/dataset/cifar/
# Out:
# --2020-10-24 09:51:48--  http://ai-atest.bj.bcebos.com/cifar-10-python.tar.gz
# Resolving ai-atest.bj.bcebos.com (ai-atest.bj.bcebos.com)... 182.61.200.229, 182.61.200.195, 2409:8c00:6c21:10ad:0:ff:b00e:67d
# Connecting to ai-atest.bj.bcebos.com (ai-atest.bj.bcebos.com)|182.61.200.229|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 170498071 (163M) [application/x-gzip]
# Saving to: ‘cifar-10-python.tar.gz’
#
# cifar-10-python.tar 100%[===================>] 162.60M  18.6MB/s    in 8.3s
#
# 2020-10-24 09:51:56 (19.6 MB/s) - ‘cifar-10-python.tar.gz’ saved [170498071/170498071]
#
# .  ..  cifar-10-python.tar.gz

# %%
BATCH_SIZE = 64
#用于训练的数据提供器
train_reader = paddle.batch(
    paddle.reader.shuffle(paddle.dataset.cifar.train10(), 
                          buf_size=128*100),           
    batch_size=BATCH_SIZE)                                
#用于测试的数据提供器
test_reader = paddle.batch(
    paddle.dataset.cifar.test10(),                            
    batch_size=BATCH_SIZE)

# %% [markdown]
# # **Step2.网络配置**
#
# **（1）网络搭建**
#
# *** **CNN网络模型**
#
# 在CNN模型中，卷积神经网络能够更好的利用图像的结构信息。下面定义了一个较简单的卷积神经网络。显示了其结构：输入的二维图像，先经过三次卷积层、池化层和Batchnorm，再经过全连接层，最后使用softmax分类作为输出层。
#
# ![](https://ai-studio-static-online.cdn.bcebos.com/98b9b702cce040fb8a874e28eae6d34ace6025a2c9444cdd954ab5f14d69cfdc)
#
# **池化**是非线性下采样的一种形式，主要作用是通过减少网络的参数来减小计算量，并且能够在一定程度上控制过拟合。通常在卷积层的后面会加上一个池化层。paddlepaddle池化默认为最大池化。是用不重叠的矩形框将输入层分成不同的区域，对于每个矩形框的数取最大值作为输出
#
# **Batchnorm**顾名思义是对每batch个数据同时做一个norm。作用就是在深度神经网络训练过程中使得每一层神经网络的输入保持相同分布的。

# %%
def convolutional_neural_network(img):
    # 第一个卷积-池化层
    conv_pool_1 = fluid.nets.simple_img_conv_pool(
        input=img,         # 输入图像
        filter_size=3,     # 滤波器的大小
        num_filters=256,    # filter 的数量。它与输出的通道相同
        pool_size=2,       # 池化核大小2*2
        pool_stride=2,     # 池化步长
        act="relu")        # 激活类型
    conv_pool_1 = fluid.layers.dropout(conv_pool_1, dropout_prob=0.5) #加入dropout
    conv_pool_1 = fluid.layers.batch_norm(conv_pool_1)
    # 第二个卷积-池化层
    conv_pool_2 = fluid.nets.simple_img_conv_pool(
        input=conv_pool_1,
        filter_size=5,
        num_filters=512,
        pool_size=2,
        pool_stride=2,
        act="relu")
    conv_pool_2 = fluid.layers.dropout(conv_pool_2, dropout_prob=0.6) #MMXXX加入dropout
    conv_pool_2 = fluid.layers.batch_norm(conv_pool_2)
    # 第三个卷积-池化层
    conv_pool_3 = fluid.nets.simple_img_conv_pool(
        input=conv_pool_2,
        filter_size=5,
        num_filters=256,
        pool_size=2,
        pool_stride=2,
        act="relu")
    conv_pool_3 = fluid.layers.dropout(conv_pool_3, dropout_prob=0.7) #MMXXX加入dropout
    conv_pool_3 = fluid.layers.batch_norm(conv_pool_3)
    # 以softmax为激活函数的全连接输出层，10类数据输出10个数字
    fc1 = fluid.layers.fc(input=conv_pool_3, size=128, act='relu')
    fc2 = fluid.layers.fc(input=fc1, size=100, act='relu')
    fc3 = fluid.layers.fc(input=fc2, size=100, act='relu')
    prediction = fluid.layers.fc(input=fc2, size=10, act='softmax')
    return prediction

# %% [markdown]
# **（2）定义数据**

# %%
#定义输入数据
data_shape = [3, 32, 32]
images = fluid.layers.data(name='images', shape=data_shape, dtype='float32')
label = fluid.layers.data(name='label', shape=[1], dtype='int64')

# %% [markdown]
# **（3）获取分类器**
#
# 下面cell里面使用了CNN方式进行分类

# %%
# 获取分类器，用cnn进行分类
predict =  convolutional_neural_network(images)

# %% [markdown]
# **（4）定义损失函数和准确率**
#
# 这次使用的是交叉熵损失函数，该函数在分类任务上比较常用。
#
# 定义了一个损失函数之后，还有对它求平均值，因为定义的是一个Batch的损失值。
#
# 同时我们还可以定义一个准确率函数，这个可以在我们训练的时候输出分类的准确率。

# %%
# 获取损失函数和准确率
cost = fluid.layers.cross_entropy(input=predict, label=label) # 交叉熵
avg_cost = fluid.layers.mean(cost)                            # 计算cost中所有元素的平均值
acc = fluid.layers.accuracy(input=predict, label=label)       #使用输入和标签计算准确率

# %% [markdown]
# **（5）定义优化方法**
#
# 这次我们使用的是Adam优化方法，同时指定学习率为0.001

# %%
# 获取测试程序
test_program = fluid.default_main_program().clone(for_test=True)

# 定义优化方法
optimizer =fluid.optimizer.Adam(learning_rate=2e-4)
optimizer.minimize(avg_cost)
print("完成")
# Out:
# 完成

# %% [markdown]
# 在上述模型配置完毕后，得到两个fluid.Program：fluid.default_startup_program() 与fluid.default_main_program() 配置完毕了。
#
# 参数初始化操作会被写入fluid.default_startup_program()
#
# fluid.default_main_program()用于获取默认或全局main program(主程序)。该主程序用于训练和测试模型。fluid.layers 中的所有layer函数可以向 default_main_program 中添加算子和变量。default_main_program 是fluid的许多编程接口（API）的Program参数的缺省值。例如,当用户program没有传入的时候， Executor.run() 会默认执行 default_main_program 。

# %% [markdown]
# # **Step3.模型训练 and Step4.模型评估**
#
# **（1）创建Executor**
#
# 首先定义运算场所 fluid.CPUPlace()和 fluid.CUDAPlace(0)分别表示运算场所为CPU和GPU
#
# Executor:接收传入的program，通过run()方法运行program。

# %%
# 定义使用CPU还是GPU，使用CPU时use_cuda = False,使用GPU时use_cuda = True
use_cuda = True
place = fluid.CUDAPlace(0) if use_cuda else fluid.CPUPlace()

# %%
# 创建执行器，初始化参数

exe = fluid.Executor(place)
exe.run(fluid.default_startup_program())
# Out:
# []

# %% [markdown]
# **(2)定义数据映射器**
#
# DataFeeder 负责将reader(读取器)返回的数据转成一种特殊的数据结构，使它们可以输入到 Executor

# %%
feeder = fluid.DataFeeder( feed_list=[images, label],place=place)

# %% [markdown]
# **（3）定义绘制训练过程的损失值和准确率变化趋势的方法draw_train_process**

# %%
all_train_iter=0
all_train_iters=[]
all_train_costs=[]
all_train_accs=[]

def draw_train_process(title,iters,costs,accs,label_cost,lable_acc):
    plt.title(title, fontsize=24)
    plt.xlabel("iter", fontsize=20)
    plt.ylabel("cost/acc", fontsize=20)
    plt.plot(iters, costs,color='red',label=label_cost) 
    plt.plot(iters, accs,color='green',label=lable_acc) 
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# **（3）训练并保存模型**
#
# Executor接收传入的program,并根据feed map(输入映射表)和fetch_list(结果获取表) 向program中添加feed operators(数据输入算子)和fetch operators（结果获取算子)。 feed map为该program提供输入数据。fetch_list提供program训练结束后用户预期的变量。
#
# 每一个Pass训练结束之后，再使用验证集进行验证，并打印出相应的损失值cost和准确率acc。

# %%
EPOCH_NUM = 60
model_save_dir = "/home/aistudio/work/catdog.inference.model"

for pass_id in range(EPOCH_NUM):
    # 开始训练
    for batch_id, data in enumerate(train_reader()):                        #遍历train_reader的迭代器，并为数据加上索引batch_id
        train_cost,train_acc = exe.run(program=fluid.default_main_program(),#运行主程序
                             feed=feeder.feed(data),                        #喂入一个batch的数据
                             fetch_list=[avg_cost, acc])                    #fetch均方误差和准确率

        
        all_train_iter=all_train_iter+BATCH_SIZE
        all_train_iters.append(all_train_iter)
        all_train_costs.append(train_cost[0])
        all_train_accs.append(train_acc[0])
        
        #每100次batch打印一次训练、进行一次测试
        if batch_id % 100 == 0:                                             
            print('Pass:%d, Batch:%d, Cost:%0.5f, Accuracy:%0.5f' % 
            (pass_id, batch_id, train_cost[0], train_acc[0]))
            

    # 开始测试
    test_costs = []                                                         #测试的损失值
    test_accs = []                                                          #测试的准确率
    for batch_id, data in enumerate(test_reader()):
        test_cost, test_acc = exe.run(program=test_program,                 #执行测试程序
                                      feed=feeder.feed(data),               #喂入数据
                                      fetch_list=[avg_cost, acc])           #fetch 误差、准确率
        test_costs.append(test_cost[0])                                     #记录每个batch的误差
        test_accs.append(test_acc[0])                                       #记录每个batch的准确率
    
    # 求测试结果的平均值
    test_cost = (sum(test_costs) / len(test_costs))                         #计算误差平均值（误差和/误差的个数）
    test_acc = (sum(test_accs) / len(test_accs))                            #计算准确率平均值（ 准确率的和/准确率的个数）
    print('Test:%d, Cost:%0.5f, ACC:%0.5f' % (pass_id, test_cost, test_acc))
    
#保存模型
# 如果保存路径不存在就创建
if not os.path.exists(model_save_dir):
    os.makedirs(model_save_dir)
print ('save models to %s' % (model_save_dir))
fluid.io.save_inference_model(model_save_dir,
                              ['images'],
                              [predict],
                              exe)
print('训练模型保存完成！')
draw_train_process("training",all_train_iters,all_train_costs,all_train_accs,"trainning cost","trainning acc")
# Out:
# Pass:0, Batch:0, Cost:2.54123, Accuracy:0.09375
# Pass:0, Batch:100, Cost:2.16230, Accuracy:0.23438
# Pass:0, Batch:200, Cost:1.91803, Accuracy:0.25000
# Pass:0, Batch:300, Cost:1.75548, Accuracy:0.42188
# Pass:0, Batch:400, Cost:1.78840, Accuracy:0.32812
# Pass:0, Batch:500, Cost:1.73667, Accuracy:0.31250
# Pass:0, Batch:600, Cost:1.83235, Accuracy:0.29688
# Pass:0, Batch:700, Cost:1.76952, Accuracy:0.39062
# Test:0, Cost:1.54033, ACC:0.43650
# Pass:1, Batch:0, Cost:1.61906, Accuracy:0.42188
# Pass:1, Batch:100, Cost:1.64907, Accuracy:0.45312
# Pass:1, Batch:200, Cost:1.66453, Accuracy:0.42188
# Pass:1, Batch:300, Cost:1.39147, Accuracy:0.50000
# Pass:1, Batch:400, Cost:1.51004, Accuracy:0.45312
# Pass:1, Batch:500, Cost:1.31009, Accuracy:0.54688
# Pass:1, Batch:600, Cost:1.44099, Accuracy:0.45312
# Pass:1, Batch:700, Cost:1.56671, Accuracy:0.39062
# Test:1, Cost:1.38396, ACC:0.49781
# Pass:2, Batch:0, Cost:1.50322, Accuracy:0.50000
# Pass:2, Batch:100, Cost:1.36776, Accuracy:0.56250
# Pass:2, Batch:200, Cost:1.46158, Accuracy:0.45312
# Pass:2, Batch:300, Cost:1.46048, Accuracy:0.46875
# Pass:2, Batch:400, Cost:1.41761, Accuracy:0.48438
# Pass:2, Batch:500, Cost:1.42891, Accuracy:0.46875
# Pass:2, Batch:600, Cost:1.26141, Accuracy:0.54688
# Pass:2, Batch:700, Cost:1.14469, Accuracy:0.57812
# Test:2, Cost:1.25081, ACC:0.54160
# Pass:3, Batch:0, Cost:1.22485, Accuracy:0.56250
# Pass:3, Batch:100, Cost:1.48161, Accuracy:0.43750
# Pass:3, Batch:200, Cost:1.26284, Accuracy:0.51562
# Pass:3, Batch:300, Cost:1.25344, Accuracy:0.54688
# Pass:3, Batch:400, Cost:0.91001, Accuracy:0.71875
# Pass:3, Batch:500, Cost:1.21158, Accuracy:0.50000
# Pass:3, Batch:600, Cost:1.16513, Accuracy:0.53125
# Pass:3, Batch:700, Cost:1.18271, Accuracy:0.62500
# Test:3, Cost:1.14429, ACC:0.59295
# Pass:4, Batch:0, Cost:1.09503, Accuracy:0.60938
# Pass:4, Batch:100, Cost:1.20415, Accuracy:0.56250
# Pass:4, Batch:200, Cost:1.24575, Accuracy:0.56250
# Pass:4, Batch:300, Cost:1.09871, Accuracy:0.56250
# Pass:4, Batch:400, Cost:1.12311, Accuracy:0.64062
# Pass:4, Batch:500, Cost:1.17740, Accuracy:0.56250
# Pass:4, Batch:600, Cost:1.18572, Accuracy:0.70312
# Pass:4, Batch:700, Cost:1.21136, Accuracy:0.54688
# Test:4, Cost:1.10373, ACC:0.60420
# Pass:5, Batch:0, Cost:0.88709, Accuracy:0.71875
# Pass:5, Batch:100, Cost:1.07036, Accuracy:0.64062
# Pass:5, Batch:200, Cost:1.14689, Accuracy:0.59375
# Pass:5, Batch:300, Cost:1.10165, Accuracy:0.53125
# Pass:5, Batch:400, Cost:1.06780, Accuracy:0.57812
# Pass:5, Batch:500, Cost:1.20718, Accuracy:0.56250
# Pass:5, Batch:600, Cost:1.15743, Accuracy:0.60938
# Pass:5, Batch:700, Cost:0.99368, Accuracy:0.68750
# Test:5, Cost:0.99328, ACC:0.64510
# Pass:6, Batch:0, Cost:1.26620, Accuracy:0.54688
# Pass:6, Batch:100, Cost:0.89934, Accuracy:0.68750
# Pass:6, Batch:200, Cost:1.12817, Accuracy:0.62500
# Pass:6, Batch:300, Cost:1.10766, Accuracy:0.53125
# Pass:6, Batch:400, Cost:0.80839, Accuracy:0.68750
# Pass:6, Batch:500, Cost:1.03596, Accuracy:0.62500
# Pass:6, Batch:600, Cost:1.03914, Accuracy:0.56250
# Pass:6, Batch:700, Cost:1.32094, Accuracy:0.53125
# Test:6, Cost:0.96016, ACC:0.66063
# Pass:7, Batch:0, Cost:0.92830, Accuracy:0.60938
# Pass:7, Batch:100, Cost:1.00753, Accuracy:0.65625
# Pass:7, Batch:200, Cost:1.20439, Accuracy:0.57812
# Pass:7, Batch:300, Cost:0.95005, Accuracy:0.64062
# Pass:7, Batch:400, Cost:0.94294, Accuracy:0.64062
# Pass:7, Batch:500, Cost:0.80389, Accuracy:0.71875
# Pass:7, Batch:600, Cost:1.03458, Accuracy:0.75000
# Pass:7, Batch:700, Cost:1.20262, Accuracy:0.57812
# Test:7, Cost:0.89818, ACC:0.68561
# Pass:8, Batch:0, Cost:0.91275, Accuracy:0.62500
# Pass:8, Batch:100, Cost:0.97251, Accuracy:0.64062
# Pass:8, Batch:200, Cost:1.06845, Accuracy:0.57812
# Pass:8, Batch:300, Cost:0.89548, Accuracy:0.71875
# Pass:8, Batch:400, Cost:1.12950, Accuracy:0.59375
# Pass:8, Batch:500, Cost:0.96488, Accuracy:0.71875
# Pass:8, Batch:600, Cost:0.87586, Accuracy:0.71875
# Pass:8, Batch:700, Cost:0.73423, Accuracy:0.73438
# Test:8, Cost:0.85665, ACC:0.69477
# Pass:9, Batch:0, Cost:1.03757, Accuracy:0.67188
# Pass:9, Batch:100, Cost:0.89674, Accuracy:0.70312
# Pass:9, Batch:200, Cost:1.04407, Accuracy:0.65625
# Pass:9, Batch:300, Cost:0.88834, Accuracy:0.71875
# Pass:9, Batch:400, Cost:1.01892, Accuracy:0.70312
# Pass:9, Batch:500, Cost:0.86384, Accuracy:0.70312
# Pass:9, Batch:600, Cost:0.98814, Accuracy:0.65625
# Pass:9, Batch:700, Cost:0.76538, Accuracy:0.71875
# Test:9, Cost:0.82879, ACC:0.70631
# Pass:10, Batch:0, Cost:1.01436, Accuracy:0.62500
# Pass:10, Batch:100, Cost:1.04596, Accuracy:0.60938
# Pass:10, Batch:200, Cost:0.79373, Accuracy:0.70312
# Pass:10, Batch:300, Cost:0.64931, Accuracy:0.84375
# Pass:10, Batch:400, Cost:0.76137, Accuracy:0.73438
# Pass:10, Batch:500, Cost:1.10783, Accuracy:0.54688
# Pass:10, Batch:600, Cost:0.98782, Accuracy:0.59375
# Pass:10, Batch:700, Cost:0.80568, Accuracy:0.68750
# Test:10, Cost:0.80798, ACC:0.71825
# Pass:11, Batch:0, Cost:1.05031, Accuracy:0.64062
# Pass:11, Batch:100, Cost:0.82071, Accuracy:0.75000
# Pass:11, Batch:200, Cost:0.87781, Accuracy:0.67188
# Pass:11, Batch:300, Cost:1.05723, Accuracy:0.65625
# Pass:11, Batch:400, Cost:0.96782, Accuracy:0.70312
# Pass:11, Batch:500, Cost:1.09625, Accuracy:0.62500
# Pass:11, Batch:600, Cost:0.89599, Accuracy:0.67188
# Pass:11, Batch:700, Cost:0.94414, Accuracy:0.62500
# Test:11, Cost:0.79190, ACC:0.72432
# Pass:12, Batch:0, Cost:0.85930, Accuracy:0.75000
# Pass:12, Batch:100, Cost:0.87525, Accuracy:0.67188
# Pass:12, Batch:200, Cost:0.94435, Accuracy:0.64062
# Pass:12, Batch:300, Cost:0.59464, Accuracy:0.78125
# Pass:12, Batch:400, Cost:0.77664, Accuracy:0.68750
# Pass:12, Batch:500, Cost:0.70015, Accuracy:0.79688
# Pass:12, Batch:600, Cost:0.81340, Accuracy:0.67188
# Pass:12, Batch:700, Cost:0.71571, Accuracy:0.71875
# Test:12, Cost:0.75609, ACC:0.73816
# Pass:13, Batch:0, Cost:0.71591, Accuracy:0.78125
# Pass:13, Batch:100, Cost:0.80616, Accuracy:0.73438
# Pass:13, Batch:200, Cost:0.67991, Accuracy:0.76562
# Pass:13, Batch:300, Cost:0.80420, Accuracy:0.70312
# Pass:13, Batch:400, Cost:0.91277, Accuracy:0.65625
# Pass:13, Batch:500, Cost:0.78454, Accuracy:0.75000
# Pass:13, Batch:600, Cost:0.86013, Accuracy:0.67188
# Pass:13, Batch:700, Cost:0.69114, Accuracy:0.75000
# Test:13, Cost:0.76477, ACC:0.73338
# Pass:14, Batch:0, Cost:0.97690, Accuracy:0.68750
# Pass:14, Batch:100, Cost:0.84407, Accuracy:0.67188
# Pass:14, Batch:200, Cost:0.80512, Accuracy:0.75000
# Pass:14, Batch:300, Cost:0.80201, Accuracy:0.71875
# Pass:14, Batch:400, Cost:0.61064, Accuracy:0.75000
# Pass:14, Batch:500, Cost:0.88565, Accuracy:0.62500
# Pass:14, Batch:600, Cost:0.67417, Accuracy:0.73438
# Pass:14, Batch:700, Cost:1.03667, Accuracy:0.71875
# Test:14, Cost:0.73633, ACC:0.74353
# Pass:15, Batch:0, Cost:1.05651, Accuracy:0.59375
# Pass:15, Batch:100, Cost:0.88057, Accuracy:0.70312
# Pass:15, Batch:200, Cost:0.91672, Accuracy:0.67188
# Pass:15, Batch:300, Cost:0.86773, Accuracy:0.67188
# Pass:15, Batch:400, Cost:0.63995, Accuracy:0.81250
# Pass:15, Batch:500, Cost:0.69770, Accuracy:0.75000
# Pass:15, Batch:600, Cost:0.76675, Accuracy:0.76562
# Pass:15, Batch:700, Cost:0.83638, Accuracy:0.70312
# Test:15, Cost:0.72249, ACC:0.74871
# Pass:16, Batch:0, Cost:0.82497, Accuracy:0.71875
# Pass:16, Batch:100, Cost:0.50069, Accuracy:0.87500
# Pass:16, Batch:200, Cost:0.89096, Accuracy:0.67188
# Pass:16, Batch:300, Cost:0.84847, Accuracy:0.71875
# Pass:16, Batch:400, Cost:0.73210, Accuracy:0.78125
# Pass:16, Batch:500, Cost:0.67519, Accuracy:0.79688
# Pass:16, Batch:600, Cost:0.83914, Accuracy:0.71875
# Pass:16, Batch:700, Cost:0.95479, Accuracy:0.73438
# Test:16, Cost:0.72771, ACC:0.74612
# Pass:17, Batch:0, Cost:0.63469, Accuracy:0.78125
# Pass:17, Batch:100, Cost:0.85995, Accuracy:0.73438
# Pass:17, Batch:200, Cost:0.79736, Accuracy:0.71875
# Pass:17, Batch:300, Cost:0.70481, Accuracy:0.73438
# Pass:17, Batch:400, Cost:0.69555, Accuracy:0.73438
# Pass:17, Batch:500, Cost:0.93831, Accuracy:0.62500
# Pass:17, Batch:600, Cost:0.69112, Accuracy:0.75000
# Pass:17, Batch:700, Cost:0.64821, Accuracy:0.75000
# Test:17, Cost:0.70664, ACC:0.75597
# Pass:18, Batch:0, Cost:0.79812, Accuracy:0.73438
# Pass:18, Batch:100, Cost:0.72450, Accuracy:0.73438
# Pass:18, Batch:200, Cost:0.85005, Accuracy:0.71875
# Pass:18, Batch:300, Cost:0.78451, Accuracy:0.73438
# Pass:18, Batch:400, Cost:0.74863, Accuracy:0.70312
# Pass:18, Batch:500, Cost:0.69315, Accuracy:0.70312
# Pass:18, Batch:600, Cost:1.05634, Accuracy:0.65625
# Pass:18, Batch:700, Cost:0.86132, Accuracy:0.73438
# Test:18, Cost:0.69804, ACC:0.76065
# Pass:19, Batch:0, Cost:0.51215, Accuracy:0.87500
# Pass:19, Batch:100, Cost:0.92826, Accuracy:0.65625
# Pass:19, Batch:200, Cost:0.66243, Accuracy:0.79688
# Pass:19, Batch:300, Cost:0.62382, Accuracy:0.73438
# Pass:19, Batch:400, Cost:0.89036, Accuracy:0.71875
# Pass:19, Batch:500, Cost:0.76858, Accuracy:0.73438
# Pass:19, Batch:600, Cost:0.80695, Accuracy:0.67188
# Pass:19, Batch:700, Cost:0.82658, Accuracy:0.75000
# Test:19, Cost:0.69101, ACC:0.76015
# Pass:20, Batch:0, Cost:0.58870, Accuracy:0.78125
# Pass:20, Batch:100, Cost:0.78084, Accuracy:0.68750
# Pass:20, Batch:200, Cost:0.77147, Accuracy:0.75000
# Pass:20, Batch:300, Cost:0.68454, Accuracy:0.78125
# Pass:20, Batch:400, Cost:0.79709, Accuracy:0.70312
# Pass:20, Batch:500, Cost:0.73569, Accuracy:0.76562
# Pass:20, Batch:600, Cost:0.42717, Accuracy:0.85938
# Pass:20, Batch:700, Cost:1.10672, Accuracy:0.60938
# Test:20, Cost:0.66541, ACC:0.77160
# Pass:21, Batch:0, Cost:0.63723, Accuracy:0.79688
# Pass:21, Batch:100, Cost:0.81401, Accuracy:0.76562
# Pass:21, Batch:200, Cost:0.73837, Accuracy:0.76562
# Pass:21, Batch:300, Cost:0.68576, Accuracy:0.76562
# Pass:21, Batch:400, Cost:0.73109, Accuracy:0.68750
# Pass:21, Batch:500, Cost:0.71502, Accuracy:0.73438
# Pass:21, Batch:600, Cost:0.74446, Accuracy:0.70312
# Pass:21, Batch:700, Cost:0.58515, Accuracy:0.76562
# Test:21, Cost:0.68474, ACC:0.76324
# Pass:22, Batch:0, Cost:0.68640, Accuracy:0.78125
# Pass:22, Batch:100, Cost:0.79839, Accuracy:0.65625
# Pass:22, Batch:200, Cost:0.62050, Accuracy:0.78125
# Pass:22, Batch:300, Cost:0.74871, Accuracy:0.78125
# Pass:22, Batch:400, Cost:0.63835, Accuracy:0.81250
# Pass:22, Batch:500, Cost:0.83697, Accuracy:0.73438
# Pass:22, Batch:600, Cost:0.58262, Accuracy:0.78125
# Pass:22, Batch:700, Cost:0.61739, Accuracy:0.78125
# Test:22, Cost:0.67922, ACC:0.76572
# Pass:23, Batch:0, Cost:0.48509, Accuracy:0.82812
# Pass:23, Batch:100, Cost:0.47428, Accuracy:0.85938
# Pass:23, Batch:200, Cost:0.71517, Accuracy:0.76562
# Pass:23, Batch:300, Cost:0.59133, Accuracy:0.76562
# Pass:23, Batch:400, Cost:0.86994, Accuracy:0.68750
# Pass:23, Batch:500, Cost:0.70435, Accuracy:0.78125
# Pass:23, Batch:600, Cost:0.80965, Accuracy:0.67188
# Pass:23, Batch:700, Cost:0.67672, Accuracy:0.78125
# Test:23, Cost:0.67081, ACC:0.77070
# Pass:24, Batch:0, Cost:0.57658, Accuracy:0.78125
# Pass:24, Batch:100, Cost:0.91415, Accuracy:0.65625
# Pass:24, Batch:200, Cost:0.72383, Accuracy:0.73438
# Pass:24, Batch:300, Cost:0.64487, Accuracy:0.78125
# Pass:24, Batch:400, Cost:0.64997, Accuracy:0.78125
# Pass:24, Batch:500, Cost:0.69062, Accuracy:0.73438
# Pass:24, Batch:600, Cost:0.74549, Accuracy:0.75000
# Pass:24, Batch:700, Cost:0.55102, Accuracy:0.82812
# Test:24, Cost:0.65161, ACC:0.77617
# Pass:25, Batch:0, Cost:0.91597, Accuracy:0.70312
# Pass:25, Batch:100, Cost:0.45329, Accuracy:0.87500
# Pass:25, Batch:200, Cost:0.53711, Accuracy:0.84375
# Pass:25, Batch:300, Cost:0.46745, Accuracy:0.82812
# Pass:25, Batch:400, Cost:0.58528, Accuracy:0.78125
# Pass:25, Batch:500, Cost:0.54179, Accuracy:0.81250
# Pass:25, Batch:600, Cost:0.54669, Accuracy:0.82812
# Pass:25, Batch:700, Cost:0.53803, Accuracy:0.81250
# Test:25, Cost:0.65553, ACC:0.77578
# Pass:26, Batch:0, Cost:0.60232, Accuracy:0.78125
# Pass:26, Batch:100, Cost:0.73969, Accuracy:0.68750
# Pass:26, Batch:200, Cost:0.46829, Accuracy:0.82812
# Pass:26, Batch:300, Cost:0.42274, Accuracy:0.85938
# Pass:26, Batch:400, Cost:0.68614, Accuracy:0.71875
# Pass:26, Batch:500, Cost:0.94242, Accuracy:0.70312
# Pass:26, Batch:600, Cost:0.53221, Accuracy:0.76562
# Pass:26, Batch:700, Cost:0.72055, Accuracy:0.75000
# Test:26, Cost:0.63527, ACC:0.78025
# Pass:27, Batch:0, Cost:0.56061, Accuracy:0.75000
# Pass:27, Batch:100, Cost:0.77720, Accuracy:0.70312
# Pass:27, Batch:200, Cost:0.69194, Accuracy:0.75000
# Pass:27, Batch:300, Cost:0.35882, Accuracy:0.90625
# Pass:27, Batch:400, Cost:0.51140, Accuracy:0.79688
# Pass:27, Batch:500, Cost:0.44025, Accuracy:0.84375
# Pass:27, Batch:600, Cost:0.59744, Accuracy:0.82812
# Pass:27, Batch:700, Cost:0.45964, Accuracy:0.85938
# Test:27, Cost:0.64129, ACC:0.78155
# Pass:28, Batch:0, Cost:0.64704, Accuracy:0.75000
# Pass:28, Batch:100, Cost:0.54789, Accuracy:0.82812
# Pass:28, Batch:200, Cost:0.71303, Accuracy:0.75000
# Pass:28, Batch:300, Cost:0.74588, Accuracy:0.70312
# Pass:28, Batch:400, Cost:0.54890, Accuracy:0.79688
# Pass:28, Batch:500, Cost:0.40289, Accuracy:0.84375
# Pass:28, Batch:600, Cost:0.49569, Accuracy:0.82812
# Pass:28, Batch:700, Cost:0.68472, Accuracy:0.76562
# Test:28, Cost:0.64994, ACC:0.77936
# Pass:29, Batch:0, Cost:0.58574, Accuracy:0.78125
# Pass:29, Batch:100, Cost:0.66205, Accuracy:0.76562
# Pass:29, Batch:200, Cost:0.48016, Accuracy:0.84375
# Pass:29, Batch:300, Cost:0.82423, Accuracy:0.73438
# Pass:29, Batch:400, Cost:0.40067, Accuracy:0.87500
# Pass:29, Batch:500, Cost:0.59423, Accuracy:0.76562
# Pass:29, Batch:600, Cost:0.70774, Accuracy:0.75000
# Pass:29, Batch:700, Cost:0.69048, Accuracy:0.75000
# Test:29, Cost:0.62420, ACC:0.78533
# Pass:30, Batch:0, Cost:0.60025, Accuracy:0.78125
# Pass:30, Batch:100, Cost:0.78684, Accuracy:0.75000
# Pass:30, Batch:200, Cost:0.45479, Accuracy:0.82812
# Pass:30, Batch:300, Cost:0.74340, Accuracy:0.76562
# Pass:30, Batch:400, Cost:1.07608, Accuracy:0.64062
# Pass:30, Batch:500, Cost:0.61826, Accuracy:0.82812
# Pass:30, Batch:600, Cost:0.65439, Accuracy:0.78125
# Pass:30, Batch:700, Cost:0.57852, Accuracy:0.78125
# Test:30, Cost:0.63330, ACC:0.78493
# Pass:31, Batch:0, Cost:0.57760, Accuracy:0.81250
# Pass:31, Batch:100, Cost:0.61969, Accuracy:0.75000
# Pass:31, Batch:200, Cost:0.61129, Accuracy:0.79688
# Pass:31, Batch:300, Cost:0.55315, Accuracy:0.82812
# Pass:31, Batch:400, Cost:0.58243, Accuracy:0.79688
# Pass:31, Batch:500, Cost:0.49961, Accuracy:0.84375
# Pass:31, Batch:600, Cost:0.56574, Accuracy:0.81250
# Pass:31, Batch:700, Cost:0.87493, Accuracy:0.71875
# Test:31, Cost:0.60845, ACC:0.79588
# Pass:32, Batch:0, Cost:0.67126, Accuracy:0.76562
# Pass:32, Batch:100, Cost:0.47790, Accuracy:0.85938
# Pass:32, Batch:200, Cost:0.52767, Accuracy:0.82812
# Pass:32, Batch:300, Cost:0.57278, Accuracy:0.81250
# Pass:32, Batch:400, Cost:0.73387, Accuracy:0.76562
# Pass:32, Batch:500, Cost:0.61463, Accuracy:0.79688
# Pass:32, Batch:600, Cost:0.57705, Accuracy:0.81250
# Pass:32, Batch:700, Cost:0.49753, Accuracy:0.81250
# Test:32, Cost:0.63046, ACC:0.78643
# Pass:33, Batch:0, Cost:0.59532, Accuracy:0.76562
# Pass:33, Batch:100, Cost:0.57495, Accuracy:0.79688
# Pass:33, Batch:200, Cost:0.46289, Accuracy:0.84375
# Pass:33, Batch:300, Cost:0.42748, Accuracy:0.84375
# Pass:33, Batch:400, Cost:0.55137, Accuracy:0.76562
# Pass:33, Batch:500, Cost:0.35568, Accuracy:0.85938
# Pass:33, Batch:600, Cost:0.68322, Accuracy:0.78125
# Pass:33, Batch:700, Cost:0.49233, Accuracy:0.78125
# Test:33, Cost:0.61286, ACC:0.79339
# Pass:34, Batch:0, Cost:0.45068, Accuracy:0.81250
# Pass:34, Batch:100, Cost:0.75018, Accuracy:0.73438
# Pass:34, Batch:200, Cost:0.51792, Accuracy:0.84375
# Pass:34, Batch:300, Cost:0.61751, Accuracy:0.82812
# Pass:34, Batch:400, Cost:0.86014, Accuracy:0.70312
# Pass:34, Batch:500, Cost:0.51585, Accuracy:0.85938
# Pass:34, Batch:600, Cost:0.54852, Accuracy:0.84375
# Pass:34, Batch:700, Cost:0.58409, Accuracy:0.79688
# Test:34, Cost:0.60502, ACC:0.79399
# Pass:35, Batch:0, Cost:0.52034, Accuracy:0.81250
# Pass:35, Batch:100, Cost:0.69577, Accuracy:0.78125
# Pass:35, Batch:200, Cost:0.61273, Accuracy:0.81250
# Pass:35, Batch:300, Cost:0.61787, Accuracy:0.78125
# Pass:35, Batch:400, Cost:0.55476, Accuracy:0.82812
# Pass:35, Batch:500, Cost:0.60143, Accuracy:0.82812
# Pass:35, Batch:600, Cost:0.51404, Accuracy:0.82812
# Pass:35, Batch:700, Cost:0.55433, Accuracy:0.84375
# Test:35, Cost:0.63914, ACC:0.78185
# Pass:36, Batch:0, Cost:0.52426, Accuracy:0.89062
# Pass:36, Batch:100, Cost:0.46682, Accuracy:0.84375
# Pass:36, Batch:200, Cost:0.29964, Accuracy:0.93750
# Pass:36, Batch:300, Cost:0.85556, Accuracy:0.73438
# Pass:36, Batch:400, Cost:0.70152, Accuracy:0.78125
# Pass:36, Batch:500, Cost:0.90844, Accuracy:0.65625
# Pass:36, Batch:600, Cost:0.62030, Accuracy:0.81250
# Pass:36, Batch:700, Cost:0.50710, Accuracy:0.79688
# Test:36, Cost:0.61240, ACC:0.78802
# Pass:37, Batch:0, Cost:0.65535, Accuracy:0.81250
# Pass:37, Batch:100, Cost:0.38913, Accuracy:0.87500
# Pass:37, Batch:200, Cost:0.63435, Accuracy:0.76562
# Pass:37, Batch:300, Cost:0.51643, Accuracy:0.85938
# Pass:37, Batch:400, Cost:0.59010, Accuracy:0.79688
# Pass:37, Batch:500, Cost:0.39672, Accuracy:0.85938
# Pass:37, Batch:600, Cost:0.73852, Accuracy:0.78125
# Pass:37, Batch:700, Cost:0.57873, Accuracy:0.76562
# Test:37, Cost:0.59170, ACC:0.79628
# Pass:38, Batch:0, Cost:0.57363, Accuracy:0.84375
# Pass:38, Batch:100, Cost:0.40779, Accuracy:0.85938
# Pass:38, Batch:200, Cost:0.62686, Accuracy:0.79688
# Pass:38, Batch:300, Cost:0.62084, Accuracy:0.78125
# Pass:38, Batch:400, Cost:0.71969, Accuracy:0.76562
# Pass:38, Batch:500, Cost:0.41693, Accuracy:0.78125
# Pass:38, Batch:600, Cost:0.47450, Accuracy:0.81250
# Pass:38, Batch:700, Cost:0.40005, Accuracy:0.84375
# Test:38, Cost:0.59335, ACC:0.79857
# Pass:39, Batch:0, Cost:0.59495, Accuracy:0.78125
# Pass:39, Batch:100, Cost:0.57262, Accuracy:0.78125
# Pass:39, Batch:200, Cost:0.31520, Accuracy:0.89062
# Pass:39, Batch:300, Cost:0.55276, Accuracy:0.82812
# Pass:39, Batch:400, Cost:0.42611, Accuracy:0.85938
# Pass:39, Batch:500, Cost:0.42264, Accuracy:0.87500
# Pass:39, Batch:600, Cost:0.44311, Accuracy:0.84375
# Pass:39, Batch:700, Cost:0.50078, Accuracy:0.82812
# Test:39, Cost:0.59429, ACC:0.79807
# Pass:40, Batch:0, Cost:0.45976, Accuracy:0.81250
# Pass:40, Batch:100, Cost:0.34587, Accuracy:0.87500
# Pass:40, Batch:200, Cost:0.37057, Accuracy:0.92188
# Pass:40, Batch:300, Cost:0.39286, Accuracy:0.84375
# Pass:40, Batch:400, Cost:0.57207, Accuracy:0.81250
# Pass:40, Batch:500, Cost:0.60994, Accuracy:0.81250
# Pass:40, Batch:600, Cost:0.73671, Accuracy:0.73438
# Pass:40, Batch:700, Cost:0.64405, Accuracy:0.78125
# Test:40, Cost:0.58861, ACC:0.79956
# Pass:41, Batch:0, Cost:0.37563, Accuracy:0.89062
# Pass:41, Batch:100, Cost:0.52322, Accuracy:0.85938
# Pass:41, Batch:200, Cost:0.48964, Accuracy:0.82812
# Pass:41, Batch:300, Cost:0.35997, Accuracy:0.85938
# Pass:41, Batch:400, Cost:0.58172, Accuracy:0.75000
# Pass:41, Batch:500, Cost:0.61716, Accuracy:0.79688
# Pass:41, Batch:600, Cost:0.46517, Accuracy:0.81250
# Pass:41, Batch:700, Cost:0.47458, Accuracy:0.81250
# Test:41, Cost:0.59829, ACC:0.79787
# Pass:42, Batch:0, Cost:0.63514, Accuracy:0.82812
# Pass:42, Batch:100, Cost:0.73261, Accuracy:0.71875
# Pass:42, Batch:200, Cost:0.87050, Accuracy:0.71875
# Pass:42, Batch:300, Cost:0.47954, Accuracy:0.82812
# Pass:42, Batch:400, Cost:0.52653, Accuracy:0.79688
# Pass:42, Batch:500, Cost:0.75033, Accuracy:0.73438
# Pass:42, Batch:600, Cost:0.47536, Accuracy:0.82812
# Pass:42, Batch:700, Cost:0.36727, Accuracy:0.82812
# Test:42, Cost:0.59177, ACC:0.79996
# Pass:43, Batch:0, Cost:0.67835, Accuracy:0.79688
# Pass:43, Batch:100, Cost:0.54978, Accuracy:0.75000
# Pass:43, Batch:200, Cost:0.37476, Accuracy:0.89062
# Pass:43, Batch:300, Cost:0.54940, Accuracy:0.87500
# Pass:43, Batch:400, Cost:0.54244, Accuracy:0.81250
# Pass:43, Batch:500, Cost:0.54556, Accuracy:0.81250
# Pass:43, Batch:600, Cost:0.49749, Accuracy:0.84375
# Pass:43, Batch:700, Cost:0.55911, Accuracy:0.82812
# Test:43, Cost:0.59551, ACC:0.79757
# Pass:44, Batch:0, Cost:0.54745, Accuracy:0.81250
# Pass:44, Batch:100, Cost:0.61774, Accuracy:0.81250
# Pass:44, Batch:200, Cost:0.42916, Accuracy:0.85938
# Pass:44, Batch:300, Cost:0.35377, Accuracy:0.90625
# Pass:44, Batch:400, Cost:0.47721, Accuracy:0.82812
# Pass:44, Batch:500, Cost:0.63793, Accuracy:0.81250
# Pass:44, Batch:600, Cost:0.42159, Accuracy:0.87500
# Pass:44, Batch:700, Cost:0.47439, Accuracy:0.81250
# Test:44, Cost:0.59670, ACC:0.79817
# Pass:45, Batch:0, Cost:0.51083, Accuracy:0.84375
# Pass:45, Batch:100, Cost:0.38547, Accuracy:0.87500
# Pass:45, Batch:200, Cost:0.45592, Accuracy:0.84375
# Pass:45, Batch:300, Cost:0.61474, Accuracy:0.81250
# Pass:45, Batch:400, Cost:0.47155, Accuracy:0.89062
# Pass:45, Batch:500, Cost:0.59670, Accuracy:0.79688
# Pass:45, Batch:600, Cost:0.40706, Accuracy:0.85938
# Pass:45, Batch:700, Cost:0.50986, Accuracy:0.84375
# Test:45, Cost:0.59092, ACC:0.79996
# Pass:46, Batch:0, Cost:0.41846, Accuracy:0.89062
# Pass:46, Batch:100, Cost:0.50730, Accuracy:0.84375
# Pass:46, Batch:200, Cost:0.42075, Accuracy:0.85938
# Pass:46, Batch:300, Cost:0.44714, Accuracy:0.84375
# Pass:46, Batch:400, Cost:0.73428, Accuracy:0.73438
# Pass:46, Batch:500, Cost:0.39837, Accuracy:0.82812
# Pass:46, Batch:600, Cost:0.45631, Accuracy:0.81250
# Pass:46, Batch:700, Cost:0.47290, Accuracy:0.85938
# Test:46, Cost:0.59183, ACC:0.80056
# Pass:47, Batch:0, Cost:0.89824, Accuracy:0.71875
# Pass:47, Batch:100, Cost:0.59445, Accuracy:0.73438
# Pass:47, Batch:200, Cost:0.39537, Accuracy:0.84375
# Pass:47, Batch:300, Cost:0.36871, Accuracy:0.85938
# Pass:47, Batch:400, Cost:0.46208, Accuracy:0.84375
# Pass:47, Batch:500, Cost:0.55111, Accuracy:0.81250
# Pass:47, Batch:600, Cost:0.56405, Accuracy:0.84375
# Pass:47, Batch:700, Cost:0.58025, Accuracy:0.71875
# Test:47, Cost:0.60108, ACC:0.79926
# Pass:48, Batch:0, Cost:0.36009, Accuracy:0.85938
# Pass:48, Batch:100, Cost:0.54857, Accuracy:0.73438
# Pass:48, Batch:200, Cost:0.50008, Accuracy:0.85938
# Pass:48, Batch:300, Cost:0.59292, Accuracy:0.81250
# Pass:48, Batch:400, Cost:0.49101, Accuracy:0.81250
# Pass:48, Batch:500, Cost:0.53211, Accuracy:0.84375
# Pass:48, Batch:600, Cost:0.47405, Accuracy:0.84375
# Pass:48, Batch:700, Cost:0.60417, Accuracy:0.79688
# Test:48, Cost:0.57635, ACC:0.80543
# Pass:49, Batch:0, Cost:0.48033, Accuracy:0.82812
# Pass:49, Batch:100, Cost:0.43805, Accuracy:0.87500
# Pass:49, Batch:200, Cost:0.55781, Accuracy:0.76562
# Pass:49, Batch:300, Cost:0.39128, Accuracy:0.85938
# Pass:49, Batch:400, Cost:0.52996, Accuracy:0.85938
# Pass:49, Batch:500, Cost:0.53866, Accuracy:0.81250
# Pass:49, Batch:600, Cost:0.41819, Accuracy:0.81250
# Pass:49, Batch:700, Cost:0.31532, Accuracy:0.92188
# Test:49, Cost:0.58210, ACC:0.80215
# Pass:50, Batch:0, Cost:0.43421, Accuracy:0.82812
# Pass:50, Batch:100, Cost:0.45803, Accuracy:0.87500
# Pass:50, Batch:200, Cost:0.30373, Accuracy:0.93750
# Pass:50, Batch:300, Cost:0.44452, Accuracy:0.84375
# Pass:50, Batch:400, Cost:0.86916, Accuracy:0.73438
# Pass:50, Batch:500, Cost:0.29674, Accuracy:0.85938
# Pass:50, Batch:600, Cost:0.54985, Accuracy:0.79688
# Pass:50, Batch:700, Cost:0.55637, Accuracy:0.78125
# Test:50, Cost:0.57410, ACC:0.80812
# Pass:51, Batch:0, Cost:0.70789, Accuracy:0.68750
# Pass:51, Batch:100, Cost:0.42963, Accuracy:0.85938
# Pass:51, Batch:200, Cost:0.46072, Accuracy:0.79688
# Pass:51, Batch:300, Cost:0.24367, Accuracy:0.90625
# Pass:51, Batch:400, Cost:0.51363, Accuracy:0.82812
# Pass:51, Batch:500, Cost:0.60496, Accuracy:0.75000
# Pass:51, Batch:600, Cost:0.50749, Accuracy:0.82812
# Pass:51, Batch:700, Cost:0.66497, Accuracy:0.78125
# Test:51, Cost:0.57906, ACC:0.80553
# Pass:52, Batch:0, Cost:0.37236, Accuracy:0.85938
# Pass:52, Batch:100, Cost:0.44423, Accuracy:0.82812
# Pass:52, Batch:200, Cost:0.58044, Accuracy:0.82812
# Pass:52, Batch:300, Cost:0.46229, Accuracy:0.84375
# Pass:52, Batch:400, Cost:0.40058, Accuracy:0.85938
# Pass:52, Batch:500, Cost:0.44625, Accuracy:0.87500
# Pass:52, Batch:600, Cost:0.40402, Accuracy:0.82812
# Pass:52, Batch:700, Cost:0.46340, Accuracy:0.85938
# Test:52, Cost:0.57120, ACC:0.81021
# Pass:53, Batch:0, Cost:0.66738, Accuracy:0.75000
# Pass:53, Batch:100, Cost:0.30162, Accuracy:0.87500
# Pass:53, Batch:200, Cost:0.65373, Accuracy:0.73438
# Pass:53, Batch:300, Cost:0.49399, Accuracy:0.76562
# Pass:53, Batch:400, Cost:0.44298, Accuracy:0.89062
# Pass:53, Batch:500, Cost:0.33567, Accuracy:0.87500
# Pass:53, Batch:600, Cost:0.21904, Accuracy:0.92188
# Pass:53, Batch:700, Cost:0.55057, Accuracy:0.82812
# Test:53, Cost:0.57450, ACC:0.80742
# Pass:54, Batch:0, Cost:0.41492, Accuracy:0.82812
# Pass:54, Batch:100, Cost:0.44586, Accuracy:0.82812
# Pass:54, Batch:200, Cost:0.48440, Accuracy:0.87500
# Pass:54, Batch:300, Cost:0.39703, Accuracy:0.79688
# Pass:54, Batch:400, Cost:0.32062, Accuracy:0.89062
# Pass:54, Batch:500, Cost:0.41188, Accuracy:0.89062
# Pass:54, Batch:600, Cost:0.21354, Accuracy:0.92188
# Pass:54, Batch:700, Cost:0.36049, Accuracy:0.89062
# Test:54, Cost:0.58912, ACC:0.80404
# Pass:55, Batch:0, Cost:0.27619, Accuracy:0.87500
# Pass:55, Batch:100, Cost:0.72041, Accuracy:0.79688
# Pass:55, Batch:200, Cost:0.50474, Accuracy:0.78125
# Pass:55, Batch:300, Cost:0.52496, Accuracy:0.76562
# Pass:55, Batch:400, Cost:0.42719, Accuracy:0.84375
# Pass:55, Batch:500, Cost:0.53565, Accuracy:0.81250
# Pass:55, Batch:600, Cost:0.61230, Accuracy:0.70312
# Pass:55, Batch:700, Cost:0.27299, Accuracy:0.92188
# Test:55, Cost:0.57055, ACC:0.80981
# Pass:56, Batch:0, Cost:0.48021, Accuracy:0.87500
# Pass:56, Batch:100, Cost:0.48126, Accuracy:0.81250
# Pass:56, Batch:200, Cost:0.47313, Accuracy:0.79688
# Pass:56, Batch:300, Cost:0.57735, Accuracy:0.78125
# Pass:56, Batch:400, Cost:0.62098, Accuracy:0.76562
# Pass:56, Batch:500, Cost:0.32327, Accuracy:0.89062
# Pass:56, Batch:600, Cost:0.48577, Accuracy:0.78125
# Pass:56, Batch:700, Cost:0.48301, Accuracy:0.84375
# Test:56, Cost:0.58230, ACC:0.80693
# Pass:57, Batch:0, Cost:0.57645, Accuracy:0.84375
# Pass:57, Batch:100, Cost:0.57646, Accuracy:0.78125
# Pass:57, Batch:200, Cost:0.35284, Accuracy:0.87500
# Pass:57, Batch:300, Cost:0.49959, Accuracy:0.84375
# Pass:57, Batch:400, Cost:0.64419, Accuracy:0.76562
# Pass:57, Batch:500, Cost:0.56648, Accuracy:0.81250
# Pass:57, Batch:600, Cost:0.37244, Accuracy:0.85938
# Pass:57, Batch:700, Cost:0.44303, Accuracy:0.85938
# Test:57, Cost:0.57094, ACC:0.80892
# Pass:58, Batch:0, Cost:0.55678, Accuracy:0.78125
# Pass:58, Batch:100, Cost:0.40954, Accuracy:0.82812
# Pass:58, Batch:200, Cost:0.32418, Accuracy:0.85938
# Pass:58, Batch:300, Cost:0.40144, Accuracy:0.81250
# Pass:58, Batch:400, Cost:0.29835, Accuracy:0.85938
# Pass:58, Batch:500, Cost:0.59446, Accuracy:0.76562
# Pass:58, Batch:600, Cost:0.45443, Accuracy:0.85938
# Pass:58, Batch:700, Cost:0.31966, Accuracy:0.85938
# Test:58, Cost:0.57252, ACC:0.80862
# Pass:59, Batch:0, Cost:0.41903, Accuracy:0.89062
# Pass:59, Batch:100, Cost:0.76150, Accuracy:0.65625
# Pass:59, Batch:200, Cost:0.48579, Accuracy:0.78125
# Pass:59, Batch:300, Cost:0.35023, Accuracy:0.85938
# Pass:59, Batch:400, Cost:0.30540, Accuracy:0.92188
# Pass:59, Batch:500, Cost:0.43404, Accuracy:0.85938
# Pass:59, Batch:600, Cost:0.42245, Accuracy:0.78125
# Pass:59, Batch:700, Cost:0.34851, Accuracy:0.87500
# Test:59, Cost:0.58361, ACC:0.80533
# save models to /home/aistudio/work/catdog.inference.model
# 训练模型保存完成！

# %% [markdown]
# # **Step5.模型预测**
#
# **（1）创建预测用的Executor**

# %%
infer_exe = fluid.Executor(place)
inference_scope = fluid.core.Scope()

# %% [markdown]
# **(2)图片预处理**
#
# 在预测之前，要对图像进行预处理。
#
# 首先将图片大小调整为32*32，接着将图像转换成一维向量，最后再对一维向量进行归一化处理。

# %%
def load_image(file):
        #打开图片
        im = Image.open(file)
        #将图片调整为跟训练数据一样的大小  32*32，                   设定ANTIALIAS，即抗锯齿.resize是缩放
        im = im.resize((32, 32), Image.ANTIALIAS)
        #建立图片矩阵 类型为float32
        im = np.array(im).astype(np.float32)
        #矩阵转置 
        im = im.transpose((2, 0, 1))                               
        #将像素值从【0-255】转换为【0-1】
        im = im / 255.0
        #print(im)       
        im = np.expand_dims(im, axis=0)
        # 保持和之前输入image维度一致
        print('im_shape的维度：',im.shape)
        return im

# %% [markdown]
# **(3)开始预测**
#
# 通过fluid.io.load_inference_model，预测器会从params_dirname中读取已经训练好的模型，来对从未遇见过的数据进行预测。

# %%
model_save_dir = "/home/aistudio/work/catdog.inference.model"
with fluid.scope_guard(inference_scope):
    #从指定目录中加载 推理model(inference model)
    [inference_program, # 预测用的program
     feed_target_names, # 是一个str列表，它包含需要在推理 Program 中提供数据的变量的名称。 
     fetch_targets] = fluid.io.load_inference_model(model_save_dir,#fetch_targets：是一个 Variable 列表，从中我们可以得到推断结果。
                                                    infer_exe)     #infer_exe: 运行 inference model的 executor
    
    infer_path='dog1.jpg'
    img = Image.open(infer_path)
    plt.imshow(img)   
    plt.show()    
    
    img = load_image(infer_path)

    results = infer_exe.run(inference_program,                 #运行预测程序
                            feed={feed_target_names[0]: img},  #喂入要预测的img
                            fetch_list=fetch_targets)          #得到推测结果
    print('results',results)
    label_list = [
        "airplane", "automobile", "bird", "cat", "deer", "dog", "frog", "horse",
        "ship", "truck"
        ]
    print("infer results: %s" % label_list[np.argmax(results[0])])
# Out:
# im_shape的维度： (1, 3, 32, 32)
# results [array([[2.30493475e-04, 4.01558791e-05, 1.36894975e-02, 1.42493676e-02,
#         8.15201104e-02, 7.92817295e-01, 8.59158245e-05, 9.72925052e-02,
#         2.60221004e-05, 4.86637437e-05]], dtype=float32)]
# infer results: dog
